# %%
# %matplotlib notebook
import numpy as np

# %%
def f_non_convex(x, y):
    return (1 - x / 2.5 + x ** 5 + y ** 3 ) * np.exp(-x ** 2 - y ** 2)

def f_convex(x, y):
    return 3/2*x**2 + 1/2*y**2

# %%
X = np.arange(-3,3,0.03)
Y = np.arange(-3,3,0.03)
X, Y = np.meshgrid(X,Y)
Z = f_convex(X,Y)
Z, X.shape, Y.shape, Z.shape
# Out:
# (array([[18.     , 17.73135, 17.4654 , ..., 17.20215, 17.4654 , 17.73135],
#         [17.91045, 17.6418 , 17.37585, ..., 17.1126 , 17.37585, 17.6418 ],
#         [17.8218 , 17.55315, 17.2872 , ..., 17.02395, 17.2872 , 17.55315],
#         ...,
#         [17.73405, 17.4654 , 17.19945, ..., 16.9362 , 17.19945, 17.4654 ],
#         [17.8218 , 17.55315, 17.2872 , ..., 17.02395, 17.2872 , 17.55315],
#         [17.91045, 17.6418 , 17.37585, ..., 17.1126 , 17.37585, 17.6418 ]]),
#  (200, 200),
#  (200, 200),
#  (200, 200))

# %%
import matplotlib.pyplot as plt
from matplotlib import cm

plt.rcParams['figure.figsize'] = [5, 5]
plt.rcParams['figure.dpi'] = 200

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
surf = ax.plot_surface(X, Y, Z, cmap=cm.rainbow, linewidth=0, antialiased=False)
fig.colorbar(surf, aspect=10)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
x = np.random.rand(3, 2)

y = np.sum(x, axis=0, keepdims=True)
x,y, y.shape
# Out:
# (array([[0.66972781, 0.49497845],
#         [0.25587778, 0.72521975],
#         [0.45644726, 0.17712551]]),
#  array([[1.38205284, 1.39732371]]),
#  (1, 2))

# %%
import math

1-math.tanh(-0.010)**2
# Out:
# 0.9999000066662889

# %%
X = np.random.rand(4,3)
Y = np.random.rand(3,4)
X.dot(Y)
# Out:
# array([[0.4989815 , 0.26426397, 0.41598838, 0.50829406],
#        [1.33069313, 0.73808939, 1.22801329, 0.94639843],
#        [1.68292557, 0.78609896, 1.3112896 , 1.02981984],
#        [0.80388013, 0.22914932, 0.39217309, 0.28458655]])

# %%
X = np.random.rand(1,2)
Y = np.random.rand(1,2)
X * Y
# Out:
# array([[0.32265816, 0.19540271]])

# %%
list(range(1,3))
# Out:
# [1, 2]
